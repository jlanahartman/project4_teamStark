# %%
#import dependencies
import pandas as pd

# %%
#read the csv file
wineDF = pd.read_csv("output_data/winemag-data-130k-v2.csv", encoding='utf8')

# %%
#review the dataframe
wineDF
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
#removed 5 columns
wineDFCleaned = wineDF.drop(columns= ["taster_name","taster_twitter_handle", "Unnamed: 0", "region_2", "region_1"])

# %%
wineDFCleaned
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
#drop NA
wineDFCleaned = wineDFCleaned.dropna()

# %%
#review the cleaned dataframe
wineDFCleaned
# Out:
#          country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# 5          Spain  Blackberry and raspberry aromas show a typical...
# 6          Italy  Here's a bright, informal red that opens with ...
# ...          ...                                                ...
# 129963    Israel  A bouquet of black cherry, tart cranberry and ...
# 129965    France  While it's rich, this beautiful dry wine also ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 1                                     Avidagos      87   15.0
# ...

# %%
#drop duplicates
wineDFCleaned = wineDFCleaned.drop_duplicates()

# %%
#review the cleaned dataframe
wineDFCleaned
# Out:
#          country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# 5          Spain  Blackberry and raspberry aromas show a typical...
# 6          Italy  Here's a bright, informal red that opens with ...
# ...          ...                                                ...
# 129963    Israel  A bouquet of black cherry, tart cranberry and ...
# 129965    France  While it's rich, this beautiful dry wine also ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 1                                     Avidagos      87   15.0
# ...

# %%
#removed 3 columns
#wineDFCleaned = wineDFCleaned.drop(columns= ["taster_name","taster_twitter_handle", "Unnamed: 0"])

# %%
#review the cleaned dataframe
wineDFCleaned
# Out:
#          country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# 5          Spain  Blackberry and raspberry aromas show a typical...
# 6          Italy  Here's a bright, informal red that opens with ...
# ...          ...                                                ...
# 129963    Israel  A bouquet of black cherry, tart cranberry and ...
# 129965    France  While it's rich, this beautiful dry wine also ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 1                                     Avidagos      87   15.0
# ...

# %%
#reset index
wineDFReset = wineDFCleaned.reset_index()

# %%
#review the cleaned dataframe
wineDFReset
# Out:
#         index   country                                        description  \
# 0           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 1           3        US  Pineapple rind, lemon pith and orange blossom ...
# 2           4        US  Much like the regular bottling from 2012, this...
# 3           5     Spain  Blackberry and raspberry aromas show a typical...
# 4           6     Italy  Here's a bright, informal red that opens with ...
# ...       ...       ...                                                ...
# 79483  129963    Israel  A bouquet of black cherry, tart cranberry and ...
# 79484  129965    France  While it's rich, this beautiful dry wine also ...
# 79485  129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 79486  129968    France  Well-drained gravel soil gives this wine its c...
# 79487  129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                   designation  points  price  \
# ...

# %%
#removed 1 column
wineDFFinal = wineDFReset.drop(columns= "index")

# %%
wineDFFinal
# Out:
#         country                                        description  \
# 0      Portugal  This is ripe and fruity, a wine that is smooth...
# 1            US  Pineapple rind, lemon pith and orange blossom ...
# 2            US  Much like the regular bottling from 2012, this...
# 3         Spain  Blackberry and raspberry aromas show a typical...
# 4         Italy  Here's a bright, informal red that opens with ...
# ...         ...                                                ...
# 79483    Israel  A bouquet of black cherry, tart cranberry and ...
# 79484    France  While it's rich, this beautiful dry wine also ...
# 79485   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 79486    France  Well-drained gravel soil gives this wine its c...
# 79487    France  Big, rich and off-dry, this is powered by inte...
#
#                                   designation  points  price  \
# 0                                    Avidagos      87   15.0
# ...

# %%
wineDFFinal.to_csv("wineDF.csv")
